# %%
from plotnine import *
from plotnine.data import *
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %% [markdown]
# Basic scatter plot

# %%
p = ggplot(aes(x='displ', y='cty'), mpg)
p + geom_point()
# Out:
# <ggplot: (8787922723633)>

# %% [markdown]
# Aesthetic mappings

# %%
p + geom_point(aes(color='factor(cyl)'))
# Out:
# <ggplot: (8787922635557)>

# %%
p + geom_point(aes(shape='factor(cyl)'))
# Out:
# <ggplot: (8787922477361)>

# %%
p + geom_point(aes(color='hwy'))
# Out:
# <ggplot: (8787922429685)>

# %% [markdown]
# Modify the color scale

# %%
p + geom_point(aes(color='hwy')) + scale_color_gradient(low='blue', high='red')
# Out:
# <ggplot: (8787922389517)>

# %%
p + geom_point(aes(size='hwy'))
# Out:
# <ggplot: (8787922195469)>

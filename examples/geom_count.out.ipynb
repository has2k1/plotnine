# %% [markdown]
# # Categorized Data Plot

# %%
import pandas as pd
import numpy as np

from plotnine import (
    ggplot,
    aes,
    geom_count,
    scale_size_continuous
)
from plotnine.data import diamonds

# %% [markdown]
# ### Categorized Data Plot
#
# *geom_count() makes the point size proportional to the number of points
# at a location*

# %%
diamonds.head()
# Out:
# </div>

# %%
ggplot(diamonds) + geom_count(aes(x='cut', y='color'))

# %% [markdown]
# We can adjust the size range of the points with `scale_size_continuous`

# %%
(
    ggplot(diamonds)
    + geom_count(aes(x='cut', y='color'))
    + scale_size_continuous(range=[1,20])
)
